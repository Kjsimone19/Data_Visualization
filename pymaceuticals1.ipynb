# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - observations
#
# 1. Based on final tumor volume, Capomulin and Ramicane seem to be more affective than Infubinol and Ceftamin
# 2. the results seem to be consistant, there are not many outliers
# 3.There is a strong correlation between mouse weight and av tumor volume, so it seems the heavier the mouse the higher the tumor volume. medicince may be less effective in heavier mice.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
dataComplete = pd.merge(study_results, mouse_metadata, how="left", on = "Mouse ID")

# Display the data table for preview
dataComplete.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
miceData = dataComplete["Mouse ID"].unique()
number_of_mice = len(miceData)
number_of_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicateMice = dataComplete[dataComplete[["Mouse ID", "Timepoint"]].duplicated() == True]
duplicateMiceID = duplicateMice["Mouse ID"].unique()
duplicateMice
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 137      g989          0           45.000000                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 1111     g989         20           54.657650                 1     Propriva
#
#          Sex  Age_months  Weight (g)
# 137   Female          21          26
# 360   Female          21          26
# 681   Female          21          26
# 869   Female          21          26
# 1111  Female          21          26

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicateMiceTotal = dataComplete.loc[dataComplete["Mouse ID"] == duplicateMiceID[0]]
duplicateMiceTotal
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleanedDataComplete=dataComplete.drop_duplicates(subset=['Mouse ID', 'Timepoint'])
cleanedDataComplete.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.

cleanedMiceData = cleanedDataComplete["Mouse ID"].unique()
cleanedNumberMice = len(cleanedMiceData)
cleanedNumberMice
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen


# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
drugRegData = cleanedDataComplete.groupby('Drug Regimen')
drugRegData

# %%
# mean, median, variance, standard deviation, and SEM of the tumor volume. 

drugRegDataMean = drugRegData["Tumor Volume (mm3)"].mean()
drugRegDataMedian = drugRegData["Tumor Volume (mm3)"].median()
drugRegDataVar = drugRegData["Tumor Volume (mm3)"].var()
drugRegDataStd = drugRegData["Tumor Volume (mm3)"].std()
drugRegDataSem = drugRegData["Tumor Volume (mm3)"].sem()


drugRegDf  = pd.DataFrame({"Mean Tumor Volume":  drugRegDataMean,
                                 "Median Tumor Volume":  drugRegDataMedian,
                                 "Tumor Volume Variance":  drugRegDataVar,
                                 "Tumor Volume Std. Dev.":  drugRegDataStd,
                                 "Tumor Volume Std. Err.":  drugRegDataSem})
drugRegDf
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.393463            50.909965              43.138803
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.
drugRegAgg= cleanedDataComplete.groupby(["Drug Regimen"])[["Tumor Volume (mm3)"]].agg(["mean","median","var","std","sem"])
drugRegAgg
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.393463  50.909965  43.138803  6.568014  0.525862
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
miceTesting = cleanedDataComplete[["Drug Regimen","Timepoint"]]

miceDrug = miceTesting["Drug Regimen"].value_counts()
miceDrug



#Use DataFrame.plot() in order to create a bar chart of the data
miceDrug.plot(kind="bar",color = "b",
                  xlabel="Drug Regimen",
                  ylabel="Number of Mice Tested")

plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
drugs = miceDrug.index.values
count = miceDrug.values

#graph build and display
plt.bar(drugs, count, color="b", align="center")
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Mice Tested')
plt.xticks(rotation=90)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
maleVsFemale = cleanedDataComplete["Sex"].value_counts()
Sex = ["Male", "Female"]
maleVsFemale.plot(kind = "pie" , autopct="%1.0f%%", ylabel = "Sex")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
diffSexes = maleVsFemale.index.values
countVal = maleVsFemale.values
plt.ylabel("Sex")
plt.pie(countVal, labels = diffSexes, autopct="%1.0f%%")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

    
drugGroup = cleanedDataComplete.groupby(["Mouse ID"])["Timepoint"].max()
drugGroup
# Out:
# Mouse ID
# a203    45
# a251    45
# a262    45
# a275    45
# a366    30
#         ..
# z435    10
# z578    45
# z581    45
# z795    45
# z969    45
# Name: Timepoint, Length: 249, dtype: int64

# %%
mergeData = pd.merge(drugGroup, cleanedDataComplete, on=("Mouse ID", "Timepoint"),how="left")
mergeData
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 2       a262         45           70.717621                 4      Placebo
# 3       a275         45           62.999356                 3     Ceftamin
# 4       a366         30           63.440686                 1     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 244     z435         10           48.710661                 0     Propriva
# 245     z578         45           30.638696                 0     Ramicane
# 246     z581         45           62.754451                 3    Infubinol
# 247     z795         45           65.741070                 3     Naftisol
# 248     z969         45           73.867845                 4     Naftisol
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)

treatments= ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

treatment = []

for drug in treatments:
    tempDF = mergeData.loc[mergeData['Drug Regimen'] == drug]
        
    finalVolumedf = tempDF.loc[tempDF['Timepoint'] == tempDF['Timepoint']]

    values = finalVolumedf['Tumor Volume (mm3)']
    treatment.append(values)
    
    quartiles = values.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    print(f'IQR for {drug}: {iqr}')

# Create empty list to fill with tumor vol data (for plotting)

#tumorVol = []






    # add subset 
    
    
    # Determine outliers using upper and lower bounds
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f'Lower Bound for {drug}: {lower_bound}')
    print(f'Upper Bound for {drug}: {upper_bound}')
    
    outliers_count = (values.loc[(finalVolumedf['Tumor Volume (mm3)'] >= upper_bound) | 
                                        (finalVolumedf['Tumor Volume (mm3)'] <= lower_bound)]).count()
    print(f'Number of {drug} outliers: {outliers_count}')
# Out:
# IQR for Capomulin: 7.781863460000004
# Lower Bound for Capomulin: 20.70456164999999
# Upper Bound for Capomulin: 51.83201549
# Number of Capomulin outliers: 0
# IQR for Ramicane: 9.098536719999998
# Lower Bound for Ramicane: 17.912664470000003
# Upper Bound for Ramicane: 54.30681135
# Number of Ramicane outliers: 0
# IQR for Infubinol: 11.477135160000003
# Lower Bound for Infubinol: 36.83290494999999
# Upper Bound for Infubinol: 82.74144559000001
# Number of Infubinol outliers: 1
# IQR for Ceftamin: 15.577752179999997
# Lower Bound for Ceftamin: 25.355449580000002
# Upper Bound for Ceftamin: 87.66645829999999
# Number of Ceftamin outliers: 0

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
flierprops = dict(marker='o', markerfacecolor='r', markersize=8, markeredgecolor='black')

# Plot boxplot
plt.boxplot(treatment, flierprops=flierprops)

# Add title and labels to boxplot
plt.title('Final Tumor Volume by Drug')
plt.ylabel('Final Tumor Volume (mm3)')
plt.xticks([1, 2, 3, 4], ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

mouse = cleanedDataComplete.loc[cleanedDataComplete['Mouse ID'] == 'a275']
plt.plot(mouse['Timepoint'], mouse['Tumor Volume (mm3)'], marker = 'o')
plt.xlabel("Time (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Capomulin Treatment of Mouse a275")
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

capomulinReg = cleanedDataComplete.loc[cleanedDataComplete['Drug Regimen'] == 'Capomulin']

# Find average tumor volume for each mouse

avTumorVolume = pd.DataFrame(capomulinReg.groupby('Mouse ID')['Tumor Volume (mm3)'].mean().sort_values()).reset_index().rename(columns={'Tumor Volume (mm3)': 'Average Volume'})

# drop duplicates
avTumorVolume = pd.merge(capomulinReg, avTumorVolume, on='Mouse ID')
cleanedAvVolume = avTumorVolume[['Weight (g)', 'Average Volume']].drop_duplicates()
#cleanedAvVolume

x = cleanedAvVolume['Weight (g)']
y = cleanedAvVolume['Average Volume']

# Create a scatter plot based on new dataframe above with circle markers and listed colors
plt.scatter(x, y)

# Add labels and title to plot
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title('Average Tumor Volume by Weight')
# Display plot
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

capomulinReg = cleanedDataComplete.loc[cleanedDataComplete['Drug Regimen'] == 'Capomulin']

# Find average tumor volume for each mouse

avTumorVolume = pd.DataFrame(capomulinReg.groupby('Mouse ID')['Tumor Volume (mm3)'].mean().sort_values()).reset_index().rename(columns={'Tumor Volume (mm3)': 'Average Volume'})

# Merge average tumor volume onto data_df and drop duplicates
avTumorVolume = pd.merge(capomulinReg, avTumorVolume, on='Mouse ID')
cleanedAvVolume = avTumorVolume[['Weight (g)', 'Average Volume']].drop_duplicates()
#cleanedAvVolume

x = cleanedAvVolume['Weight (g)']
y = cleanedAvVolume['Average Volume']

# Calculate correlation 
correlation = st.pearsonr(x,y)


print(f"""The correlation between weight and average tumor volume
on the Capomulin regimen is {round(correlation[0],2)}.""")

# Plot lin regression 
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")

# Annotate lin regression
plt.annotate(line_eq,(20,37),fontsize=15,color="red")

plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title('Average Tumor Volume by Weight')
plt.show()
# Out:
# The correlation between weight and average tumor volume
# on the Capomulin regimen is 0.84.
